# %% [markdown]
# ### This notebook will parse the data structure function time data and plot a graph of the execution times of insert, search and delete functions for Queue array,Queue list, Sorted list and BST

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the function data
df = pd.read_csv("function_time_data.csv")
df.head(12)
# Out:
#         data_structure operation  input_size  data_size  time_nano
# 0              q_array    insert          10          7        125
# 1              q_array    search          10          7        189
# 2              q_array    delete          10          6         93
# 3               q_list    insert          10          7        175
# 4               q_list    search          10          7        102
# 5               q_list    delete          10          6        255
# 6          sorted_list    insert          10          7        222
# 7          sorted_list    search          10          7        113
# 8          sorted_list    delete          10          7        153
# 9   binary_search_tree    insert          10          7        310
# 10  binary_search_tree    search          10          7        202
# 11  binary_search_tree    delete          10          7        366

# %%
df.tail(12)
# Out:
#          data_structure operation  input_size  data_size  time_nano
# 648             q_array    insert       10240       6437        136
# 649             q_array    search       10240       6437      55703
# 650             q_array    delete       10240       6436         68
# 651              q_list    insert       10240       6437        753
# 652              q_list    search       10240       6437      23259
# 653              q_list    delete       10240       6436        431
# 654         sorted_list    insert       10240       6437      52542
# 655         sorted_list    search       10240       6437      60713
# 656         sorted_list    delete       10240       6436      60114
# 657  binary_search_tree    insert       10240       6437        699
# 658  binary_search_tree    search       10240       6437        586
# 659  binary_search_tree    delete       10240       6437        609

# %%
# create dataframes for each operation
insert_df = df[df['operation']=='insert']
delete_df = df[df['operation']=='delete']
search_df = df[df['operation']=='search']

# %%
insert_df.head(12)
# Out:
#         data_structure operation  input_size  data_size  time_nano
# 0              q_array    insert          10          7        125
# 3               q_list    insert          10          7        175
# 6          sorted_list    insert          10          7        222
# 9   binary_search_tree    insert          10          7        310
# 12             q_array    insert          20         15         85
# 15              q_list    insert          20         15        127
# 18         sorted_list    insert          20         15        178
# 21  binary_search_tree    insert          20         15        327
# 24             q_array    insert          40         28        101
# 27              q_list    insert          40         28        122
# 30         sorted_list    insert          40         28        202
# 33  binary_search_tree    insert          40         28        264

# %%
delete_df.head(12)
# Out:
#         data_structure operation  input_size  data_size  time_nano
# 2              q_array    delete          10          6         93
# 5               q_list    delete          10          6        255
# 8          sorted_list    delete          10          7        153
# 11  binary_search_tree    delete          10          7        366
# 14             q_array    delete          20         14         71
# 17              q_list    delete          20         14        158
# 20         sorted_list    delete          20         15        172
# 23  binary_search_tree    delete          20         15        373
# 26             q_array    delete          40         27         62
# 29              q_list    delete          40         27         97
# 32         sorted_list    delete          40         28        179
# 35  binary_search_tree    delete          40         27        358

# %%
search_df.head(12)
# Out:
#         data_structure operation  input_size  data_size  time_nano
# 1              q_array    search          10          7        189
# 4               q_list    search          10          7        102
# 7          sorted_list    search          10          7        113
# 10  binary_search_tree    search          10          7        202
# 13             q_array    search          20         15        239
# 16              q_list    search          20         15        112
# 19         sorted_list    search          20         15        122
# 22  binary_search_tree    search          20         15        111
# 25             q_array    search          40         28        381
# 28              q_list    search          40         28        156
# 31         sorted_list    search          40         28        143
# 34  binary_search_tree    search          40         28         88

# %%
# plot graph for insert operation

# reshape the data
insert_df = insert_df.pivot_table(
    index='data_size',
    columns='data_structure',
    values='time_nano',
    aggfunc='mean')
insert_df
# Out:
# data_structure  binary_search_tree  q_array  q_list  sorted_list
# data_size
# 7                            307.6    133.8   193.6        200.8
# 15                           390.0     85.0   137.0        190.4
# 28                           270.0     87.2   119.4        227.0
# 53                           403.2     91.2   135.2       4139.2
# 102                          431.8     90.2   119.8        462.2
# 206                          366.8     83.6   147.6       1132.0
# 400                          401.2     82.0   135.8       1394.8
# 810                          470.2     99.8   147.2       3757.8
# 1617                         437.8     88.4   154.6       7114.4
# 3219                         463.4     68.4   131.2      14627.2
# 6437                         607.0     90.4   281.2      48831.2

# %%
# plot graph of time against input size for each data-structure

plt.figure(figsize=(10,8))
insert_time_plot = sns.lineplot(
                        data=insert_df,
                        markers=True,
                        dashes=False,
                   )
insert_time_plot.set_xscale('log') # change x-axis to log scale
insert_time_plot.set_yscale('log') # change y-axis to log scale
insert_time_plot.set(
    xlabel = "Input Size(log scale)",
    ylabel = "Mean Execution Time in nanoseconds (log scale)",
    title = "Insertion Time"
)
sns.despine() # remove top and right border
plt.legend(
    title="Data Structure", 
    loc="upper left",
    fontsize=12
)
# # save the plot
plt.savefig('insert_time.png', bbox_inches='tight')
plt.show()

# %%
# plot graph for search operation

# reshape the data
search_df = search_df.pivot_table(
    index='data_size',
    columns='data_structure',
    values='time_nano',
    aggfunc='mean')
search_df
# Out:
# data_structure  binary_search_tree  q_array   q_list  sorted_list
# data_size
# 7                            204.2    200.0    115.2        158.4
# 15                           134.4    256.2    125.2        141.6
# 28                           120.0    400.2    154.4        170.6
# 53                           145.4    679.2    239.8        290.6
# 102                          147.2   1245.8    395.0        424.6
# 206                          143.0   2389.0    729.4        731.6
# 400                          145.4   4456.0   1339.0       1374.6
# 810                          189.8   8738.2   3065.4       4030.8
# 1617                         261.4  15181.6   5681.8       7952.2
# 3219                         226.8  26849.6   9154.8      16170.2
# 6437                         326.8  52124.8  20727.8      58667.0

# %%
# plot graph of time against input size for each data-structure

plt.figure(figsize=(10,8))
search_time_plot = sns.lineplot(
                        data=search_df,
                        markers=True,
                        dashes=False,
                   )
search_time_plot.set_xscale('log') # change x-axis to log scale
search_time_plot.set_yscale('log') # change y-axis to log scale
search_time_plot.set(
    xlabel = "Input Size(log scale)",
    ylabel = "Mean Execution Time in nanoseconds (log scale)",
    title = "Search Time"
)
sns.despine() # remove top and right border
plt.legend(
    title="Data Structure", 
    loc="upper left",
    fontsize=12
)
# # save the plot
plt.savefig('search_time.png', bbox_inches='tight')
plt.show()

# %%
# plot graph for delete operation

# reshape the data
delete_df = delete_df.pivot_table(
    index='data_size',
    columns='data_structure',
    values='time_nano',
    aggfunc='mean')
delete_df
# Out:
# data_structure  binary_search_tree  q_array  q_list  sorted_list
# data_size
# 6                           438.00    101.2   312.0          NaN
# 7                           369.25      NaN     NaN       180.80
# 14                             NaN     85.4   163.6          NaN
# 15                          394.40      NaN     NaN       172.60
# 27                          358.00     72.2   116.6          NaN
# 28                          312.50      NaN     NaN       201.20
# 52                             NaN     76.2   101.8          NaN
# 53                          497.20      NaN     NaN       294.00
# 101                            NaN     77.4   109.6          NaN
# 102                         378.60      NaN     NaN       461.60
# 205                            NaN     79.4   111.4          NaN
# 206                         377.40      NaN     NaN       816.20
# 399                            NaN     98.0   106.0          NaN
# 400                         459.40      NaN     NaN      1451.80
# 809                            NaN    125.0   171.8          NaN
# 810                         572.40      NaN     NaN      4083.40
# 1616                           NaN     77.6   153.6          NaN
# 1617                        543.80      NaN     NaN      8171.80
# 3218                           NaN     64.4   132.0          NaN
# 3219                        473.80      NaN     NaN     16249.00
# 6436                           NaN     68.4   214.0     60114.00
# 6437                        529.60      NaN     NaN     61504.75

# %%
# plot graph of time against input size for each data-structure

plt.figure(figsize=(10,8))
delete_time_plot = sns.lineplot(
                        data=delete_df,
                        markers=True,
                        dashes=False,
                   )
delete_time_plot.set_xscale('log') # change x-axis to log scale
delete_time_plot.set_yscale('log') # change y-axis to log scale
delete_time_plot.set(
    xlabel = "Input Size(log scale)",
    ylabel = "Mean Execution Time in nanoseconds (log scale)",
    title = "Deletion Time"
)
sns.despine() # remove top and right border
plt.legend(
    title="Data Structure", 
    loc="upper left",
    fontsize=12
)
# # save the plot
plt.savefig('delete_time.png', bbox_inches='tight')
plt.show()
